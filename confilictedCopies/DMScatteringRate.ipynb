# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
V_EARTH = 240 # km/s
V_ESCAPE = 500 # km/s
V_DISPERSION = 150 # km/s

HELPER_CONST = - V_DISPERSION^2/V_EARTH * (np.sqrt(np.pi/2)*V_DISPERSION*np.exp(-V_EARTH**2/(2*V_DISPERSION**2))* (scipy.special.erf(np.sqrt(V_ESCAPE**2-V_EARTH**2))-))

# %%
V_ESCAPE-V_EARTH, np.sqrt(V_ESCAPE**2-V_EARTH**2)
# Out:
# (297, 480.38422122297067)

# %%
def get_v_min(omega,q, DMmass):
    return omega/q+q/DMmass

def get_mean_inverse_DM_speed(v,):
    pass

def get_theta_integral(v, ):
    '''
    v: an array like object
    '''
    if
