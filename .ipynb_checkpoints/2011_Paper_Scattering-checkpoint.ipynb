# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.special import factorial
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import math
from IPython.display import Latex

# %%
c=2.998*10**8 #in m/s
v0 = 220*1000/c
v_esc = 500*10**3/c 
v_E = 240*1000/c 
#w_minus = 60*10**-3
#w_plus = 20*10**-3
ratio=v_esc/v0
N0 = v0**3*np.pi*(np.sqrt(np.pi)*scipy.special.erf(ratio)-2*ratio*np.exp(-ratio**2))
#dm_density = 0.4 #GeV/cm^3, plus minus 0.1
a0 = 2.68e-4 #eV^-1
target_density = 1.31e24 #GeV/cm^3
#f=70
#V=0.543*5.064225
Z=14 #silicon
dm_density = 0.3e9 #eV/cm^3, plus minus 0.1
Si_nucleus_mass = 931368088 #eV
w0=60e-3 #eV
proton_mass= 938.272e6 #eV
q0 = 56e3 #eV

# %%
def reducedMass(m1, m2):
    return m1*m2/(m1+m2)

# %%
class NaturalAndSI_Conversion:
    def __init__(self):
        self.c=2.998*10**8
        self.planck = 6.626070e-34 #in J*s
        self.h_bar = self.planck/(2*np.pi)
        self.h_bar_eV = 6.582*10**(-16)
        self.eV = 1.602176634e-19 #J
        self.electron_charge = 1.602176e-19 #C
    def massConversion(self, m, toSI=True):
        if toSI:
            return m*self.eV/(self.c**2)
        else:
            return m*self.c**2/self.eV
    def speedConversion(self,v, toSI=True):
        if toSI:
            return v*self.c
        else:
            return v/self.c
    def momentumConversion(self, p, toSI=True):
        return p*self.massConversion(1, toSI)*self.speedConversion(1,toSI)
    def lengthConversion(self, length, toSI=True):
            if toSI:
                return self.h_bar_eV/self.c * length
            else:
                return length*self.c/self.h_bar_eV

# %%
print(1/NaturalAndSI_Conversion().lengthConversion(1,True))
# Out:
# 4.5548465512002435e+23

# %%
def inverseMeanFunction_sol1(v_min, m_chi, const):
    summ = np.sqrt(np.pi)*v0*(scipy.special.erf((v_min+v_E)/v0)-scipy.special.erf((v_min-v_E)/v0))
    summ -= 4*np.exp(-v_esc**2/v0**2)*v_E
    return summ*const

def inverseMeanFunction_sol2(v_min, m_chi, const):
    summ = np.sqrt(np.pi)*v0*(scipy.special.erf(v_esc/v0)-scipy.special.erf((v_min-v_E)/v0))
    summ -= 2*np.exp(-v_esc**2/v0**2)*(v_esc-v_min+v_E)
    return summ*const

def inverseMeanFunction(v_min, m_chi, const = v0**2*np.pi/(2*v_E*N0)):
    """
    Returns the inverse mean value for any given v_min.  
    Parameters:
        v_min: input velocity
        m_chi: mass of dark matter
        const: scaling value for graphing.  As a default, it gives the true scale of the equation
    """
    if v_min>v_esc+v_E:
        return 0
    elif v_min>v_esc-v_E:
        return inverseMeanFunction_sol2(v_min,m_chi, const)
    else: 
        return inverseMeanFunction_sol1(v_min,m_chi, const)

# %%
def v_min(q,m_chi, n): #q in keV
    return n*w0/q+q/(2*m_chi)

# %%
def R_over_q_one_n(q,n, m_chi, N_T, sigma): #q in keV
    q=q*1000
    reducedmass = reducedMass(m_chi, proton_mass) #in eV
    constants = N_T*dm_density/m_chi * Z**2*sigma/(2*reducedmass**2)
    inside_summation = (q/math.factorial(n)) 
    inside_summation*=(q/q0)**(2*n)*np.exp(-(q/q0)**2)*inverseMeanFunction(v_min(q,m_chi,n),m_chi)
    inside_summation*=Screening(q)
    return constants*inside_summation *2.998*10e10 *3.15576e7 *1000 #convertion to [kg year keV]^-1

# %%
q_range = np.linspace(0,2.5,100)
q_range = 10**q_range

# %%
def Screening(q):
    ThomasFermi = 0.37 *a0
    return (ThomasFermi*q)**4/(1+(ThomasFermi*q)**2)**2

# %%
#what is NT?
NT = 6.022e23/(28.085e-3)
deriv = [[R_over_q_one_n(q,n,40e6,NT, 1e-42) for q in q_range] for n in range(1,11)]

# %%
for i in range(10):
    plt.plot(q_range, deriv[i], color="blue", alpha=0.7)
plt.yscale("log")
plt.xscale("log")
plt.xlabel("q (keV)")
#plt.vlines(40e6*v0/1000, 10**-8, 1, color="grey", alpha=0.5)
plt.ylim([1e-8,10])
plt.show()

# %%
def R_over_q_one(q,n_max, m_chi, N_T, sigma):
    total=0
    for n in range(1,n_max+1):
        total+=R_over_q_one_n(q,n, m_chi, N_T, sigma)
    return total

# %%
def scatteringRate(m_chi, n_max, N_T):
    bounds = [0.5,1000]
    summ = 0
    for n in range(1,n_max+1):
        summ+=scipy.integrate.quad(R_over_q_one, 
                                bounds[0], bounds[1], args = (n,m_chi, N_T,1), limit=100)

# %%
def crossSection(m_chi, n_max, N_T):
    rate = scatteringRate(m_chi, n_max, N_T)
    if rate==0:
        return None
    return 1/scatteringRate(m_chi, n_max, N_T)
